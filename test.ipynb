# %%
from utils import *
from eoscsp import *
from greedy import *
from dcop import *
from sdcop import s_dcop
from auction import *

# %% [markdown]
# ## Générateur d'instances aléatoires

# %%
eoscsp = generate_random_esop_instance(4, 3, 6)
eoscsp.plot_schedule()

# %% [markdown]
# ## Greedy algorithme

# %%
schedule,r = greedy_eoscsp_solver(eoscsp)
eoscsp.plot_schedule(schedule)

# %% [markdown]
# # DCOP

# %%
schedule = s_dcop(eoscsp)
eoscsp.plot_schedule(schedule)
# Out:
# Reward of sdcop:  133.94420452054064

# %% [markdown]
# ## psi algorithme

# %%
schedule = psi_solver(eoscsp)
eoscsp.plot_schedule(schedule)
# Out:
# Reward of psi:  256.0596949081043

# %% [markdown]
# ## ssi algorithme

# %%
schedule = ssi_solver(eoscsp)
eoscsp.plot_schedule(schedule)
# Out:
# Reward of ssi:  256.0596949081043
